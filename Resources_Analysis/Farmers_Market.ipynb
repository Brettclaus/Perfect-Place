# %%
import pandas as pd

# %%
# %pwd
# Out:
# '/Users/spicysara/Project_3'

# %%
farmers_market_df = pd.read_csv("./farmers_markets_from_usda.csv")

farmers_market_df.head()
# Out:
#       FMID                                        MarketName  \
# 0  1018261   Caledonia Farmers Market Association - Danville
# 1  1018318                 Stearns Homestead Farmers' Market
# 2  1009364                 106 S. Main Street Farmers Market
# 3  1010691               10th Steet Community Farmers Market
# 4  1002454                              112st Madison Avenue
#
#                                              Website  \
# 0  https://sites.google.com/site/caledoniafarmers...
# 1                    http://www.StearnsHomestead.com
# 2             http://thetownofsixmile.wordpress.com/
# 3                                                NaN
# 4                                                NaN
#
#                                             Facebook Twitter Youtube  \
# 0  https://www.facebook.com/Danville.VT.Farmers.M...     NaN     NaN
# 1                      StearnsHomesteadFarmersMarket     NaN     NaN
# ...

# %%
farmers_market_df.dtypes
# Out:
# FMID               int64
# MarketName        object
# Website           object
# Facebook          object
# Twitter           object
# Youtube           object
# OtherMedia        object
# street            object
# city              object
# County            object
# State             object
# zip               object
# Season1Date       object
# Season1Time       object
# Season2Date       object
# Season2Time       object
# Season3Date       object
# Season3Time       object
# Season4Date       object
# Season4Time       object
# x                float64
# y                float64
# Location          object
# Credit            object
# WIC               object
# WICcash           object
# SFMNP             object
# SNAP              object
# Organic           object
# Bakedgoods        object
# Cheese            object
# Crafts            object
# Flowers           object
# Eggs              object
# Seafood           object
# Herbs             object
# Vegetables        object
# ...

# %%
columns_removed = ["FMID", "Facebook", "Twitter", "Website", "Youtube", "OtherMedia", "Credit", "Coffee", 
                   "Beans", "Fruits", "Grains", "Juices", "Mushrooms", "PetFood", "Tofu", 
                   "WildHarvested", "updateTime", "Maple", "Meat", "Nursery","Nuts", "Plants", 
                   "Poultry","Prepared", "Soap", "Trees", "Wine", "Bakedgoods", "Cheese",
                   "Crafts","Flowers","Eggs", "Seafood", "Herbs", "Vegetables", "Honey", "Jams", 
                   "Season1Date","Season1Time", "Season2Date", "Season4Date", "Season4Time", "x", 
                   "y", "Location", "WIC", "WICcash", "SFMNP", "SNAP", "Organic", "Season2Time", "Season3Date",
                   "Season3Time"]

farmers_market_df.drop(columns=columns_removed, inplace=True)

farmers_market_df
# Out:
#                                             MarketName  \
# 0      Caledonia Farmers Market Association - Danville
# 1                    Stearns Homestead Farmers' Market
# 2                    106 S. Main Street Farmers Market
# 3                  10th Steet Community Farmers Market
# 4                                 112st Madison Avenue
# ...                                                ...
# 8799                    Zia Bernalillo Farmers' Market
# 8800                         Zimmerman Farmers' Market
# 8801                        Zion Canyon Farmers Market
# 8802                         Zionsville Farmers Market
# 8803                         Zona Rosa Farmers' Market
#
#                           street         city      County           State  \
# 0                            NaN     Danville   Caledonia         Vermont
# 1                6975 Ridge Road       Parma     Cuyahoga            Ohio
# 2             106 S. Main Street     Six Mile     Pickens  South Carolina
# ...

# %%
farmers_market_df.sort_values(by="city", inplace=True)

farmers_market_df
# Out:
#                                   MarketName                         street  \
# 8190                              Wakefield             8100 Braddock Road
# 7995   Uptown Fresh Healthy Lifestyle Market                3248 Bailey Ave
# 1224  Charlestown Land Trust Farmers' Market    4150 Old Post Road (Rt. 1A)
# 2702                 Festival Farmers Market                942 Main Street
# 2970           Garden Station Sunday Market             509 East 4th Street
# ...                                      ...                            ...
# 8013  Urban Oasis Farmers Market on the Move                            NaN
# 8512        Westside Tailgate Farmers Market                            NaN
# 8669       Winter Sun Farms New Paltz Market               Broadhead Avenue
# 8670          Winter Sun Farms Vassar Market  Chapin Ave. and Dutchess Ave.
# 8765      YMCA Farmers Market and Veggie Van                            NaN
#
#                    city      County         State    zip
# ...

# %%
# %pwd
# Out:
# '/Users/spicysara/Project_3'

# %%
output_csv_path = '/Users/spicysara/Project_3/cleaned_farmers_market.csv'

farmers_market_df.to_csv(output_csv_path, index=False)

# %%
farmers_market_df
# Out:
#                                   MarketName                         street  \
# 8190                              Wakefield             8100 Braddock Road
# 7995   Uptown Fresh Healthy Lifestyle Market                3248 Bailey Ave
# 1224  Charlestown Land Trust Farmers' Market    4150 Old Post Road (Rt. 1A)
# 2702                 Festival Farmers Market                942 Main Street
# 2970           Garden Station Sunday Market             509 East 4th Street
# ...                                      ...                            ...
# 8013  Urban Oasis Farmers Market on the Move                            NaN
# 8512        Westside Tailgate Farmers Market                            NaN
# 8669       Winter Sun Farms New Paltz Market               Broadhead Avenue
# 8670          Winter Sun Farms Vassar Market  Chapin Ave. and Dutchess Ave.
# 8765      YMCA Farmers Market and Veggie Van                            NaN
#
#                    city      County         State    zip
# ...

# %%
farmers_market_df.dropna(subset=['city'], inplace=True)

# %%
farmers_market_df
# Out:
#                                   MarketName  \
# 8190                              Wakefield
# 7995   Uptown Fresh Healthy Lifestyle Market
# 1224  Charlestown Land Trust Farmers' Market
# 2702                 Festival Farmers Market
# 2970           Garden Station Sunday Market
# ...                                      ...
# 7900                 Tularosa Farmers Market
# 8154                  Volcano Farmers Market
# 8523               Wheatland Farmers' Market
# 8716         Woodstock Summer Farmers Market
# 8717         Woodstock Winter Farmers Market
#
#                                     street               city      County  \
# 8190                   8100 Braddock Road          Annandale      Fairfax
# 7995                       3248 Bailey Ave            Buffalo        Erie
# 1224           4150 Old Post Road (Rt. 1A)   Charlestown, RI   Washington
# 2702                       942 Main Street         Cobleskill   Schoharie
# ...

# %%
farmers_market_df.head()
# Out:
#                                   MarketName                       street  \
# 8190                              Wakefield           8100 Braddock Road
# 7995   Uptown Fresh Healthy Lifestyle Market              3248 Bailey Ave
# 1224  Charlestown Land Trust Farmers' Market  4150 Old Post Road (Rt. 1A)
# 2702                 Festival Farmers Market              942 Main Street
# 2970           Garden Station Sunday Market           509 East 4th Street
#
#                    city      County         State    zip
# 8190         Annandale      Fairfax      Virginia  22003
# 7995            Buffalo        Erie      New York  14215
# 1224   Charlestown, RI   Washington  Rhode Island   2813
# 2702         Cobleskill   Schoharie      New York  12043
# 2970             Dayton  Montgomery          Ohio  45402

# %%
columns_to_remove = ["street"]

farmers_market_df.drop(columns=columns_to_remove, inplace=True)

# %%
farmers_market_df = farmers_market_df[farmers_market_df['city'] != '-']

farmers_market_df
# Out:
#                                   MarketName               city      County  \
# 8190                              Wakefield          Annandale      Fairfax
# 7995   Uptown Fresh Healthy Lifestyle Market            Buffalo        Erie
# 1224  Charlestown Land Trust Farmers' Market   Charlestown, RI   Washington
# 2702                 Festival Farmers Market         Cobleskill   Schoharie
# 2970           Garden Station Sunday Market              Dayton  Montgomery
# ...                                      ...                ...         ...
# 7900                 Tularosa Farmers Market           tularosa       Otero
# 8154                  Volcano Farmers Market            volcano      Hawaii
# 8523               Wheatland Farmers' Market          wheatland      Platte
# 8716         Woodstock Summer Farmers Market          woodstock     McHenry
# 8717         Woodstock Winter Farmers Market          woodstock     McHenry
#
#              State    zip
# 8190      Virginia  22003
# ...

# %%
farmers_market_df['city'] = farmers_market_df['city'].str.capitalize()

farmers_market_df.sort_values(by="city", inplace=True, key=lambda x: x.str.lower())

farmers_market_df
# Out:
# /var/folders/pc/lh7ggrp50991f9d12_27lnl40000gn/T/ipykernel_90071/1172800555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   farmers_market_df['city'] = farmers_market_df['city'].str.capitalize()
# /var/folders/pc/lh7ggrp50991f9d12_27lnl40000gn/T/ipykernel_90071/1172800555.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   farmers_market_df.sort_values(by="city", inplace=True, key=lambda x: x.str.lower())
#                                   MarketName               city      County  \
# ...

# %%
farmers_market_df = farmers_market_df.copy()
farmers_market_df['city'] = farmers_market_df['city'].str.capitalize()
farmers_market_df.sort_values(by="city", inplace=True, key=lambda x: x.str.lower())

farmers_market_df
# Out:
#                                   MarketName               city      County  \
# 8190                              Wakefield          annandale      Fairfax
# 7995   Uptown Fresh Healthy Lifestyle Market            buffalo        Erie
# 1224  Charlestown Land Trust Farmers' Market   charlestown, ri   Washington
# 2702                 Festival Farmers Market         cobleskill   Schoharie
# 2970           Garden Station Sunday Market              dayton  Montgomery
# ...                                      ...                ...         ...
# 8796               Zeeland Main Place Market            Zeeland      Ottawa
# 8797      Zelienople-Harmony Farmer's Market         Zelienople      Butler
# 8800               Zimmerman Farmers' Market         Zimmerman    Sherburne
# 1377           City of Zion's Farmers Market               Zion        Lake
# 8802               Zionsville Farmers Market         Zionsville       Boone
#
#              State    zip
# 8190      Virginia  22003
# ...

# %%
farmers_market_df
# Out:
#                                   MarketName               city      County  \
# 8190                              Wakefield          annandale      Fairfax
# 7995   Uptown Fresh Healthy Lifestyle Market            buffalo        Erie
# 1224  Charlestown Land Trust Farmers' Market   charlestown, ri   Washington
# 2702                 Festival Farmers Market         cobleskill   Schoharie
# 2970           Garden Station Sunday Market              dayton  Montgomery
# ...                                      ...                ...         ...
# 8796               Zeeland Main Place Market            Zeeland      Ottawa
# 8797      Zelienople-Harmony Farmer's Market         Zelienople      Butler
# 8800               Zimmerman Farmers' Market         Zimmerman    Sherburne
# 1377           City of Zion's Farmers Market               Zion        Lake
# 8802               Zionsville Farmers Market         Zionsville       Boone
#
#              State    zip
# 8190      Virginia  22003
# ...

# %%
farmers_market_df['city'] = farmers_market_df['city'].str.capitalize()
farmers_market_df.sort_values(by="city", inplace=True, ascending=True, key=lambda x: x.str.casefold())

# %%
farmers_market_df
# Out:
#                                   MarketName               city      County  \
# 8190                              Wakefield          annandale      Fairfax
# 7995   Uptown Fresh Healthy Lifestyle Market            buffalo        Erie
# 1224  Charlestown Land Trust Farmers' Market   charlestown, ri   Washington
# 2702                 Festival Farmers Market         cobleskill   Schoharie
# 2970           Garden Station Sunday Market              dayton  Montgomery
# ...                                      ...                ...         ...
# 8796               Zeeland Main Place Market            Zeeland      Ottawa
# 8797      Zelienople-Harmony Farmer's Market         Zelienople      Butler
# 8800               Zimmerman Farmers' Market         Zimmerman    Sherburne
# 1377           City of Zion's Farmers Market               Zion        Lake
# 8802               Zionsville Farmers Market         Zionsville       Boone
#
#              State    zip
# 8190      Virginia  22003
# ...

# %%
farmers_market_df.to_csv('farmers_market_cleaned2.csv', index=False)
